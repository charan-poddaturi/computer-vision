# %%
import cv2
image = cv2.imread('python.webp')
if image is None:
    print("Could not read the image.")
else:
    h,w,c = image.shape
    print(f"Height: {h}, Width: {w}, Channels: {c}")
# Out:
# Height: 261, Width: 500, Channels: 3
