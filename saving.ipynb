# %%
import cv2
image = cv2.imread('python.webp')
if image is None:
    print("Error: Could not read the image.")
else:
    print("Image saved successfully.")
    success = cv2.imwrite("saved.webp",image)
    if success:
        print("Image saved successfully.")
    else:
        print("Error: Could not save the image.")
# Out:
# Image saved successfully.
# Image saved successfully.
